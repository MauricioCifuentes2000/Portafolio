# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Initialize an empty list to store durations of movies
freq_duration = []
num_of_movies = 0

# Iterate over the DataFrame rows using iterrows()
for idx, row in netflix_df.iterrows():
    if row["type"] == "Movie":
        freq_duration.append(row["duration"])
        num_of_movies += 1

num_of_movies, freq_duration
# Out:
# (4677,
#  [93,
#   78,
#   80,
#   123,
#   95,
#   119,
#   118,
#   143,
#   103,
#   89,
#   91,
#   149,
#   144,
#   124,
#   110,
#   128,
#   117,
#   100,
#   99,
#   95,
#   102,
#   104,
#   99,
#   105,
#   125,
#   119,
#   81,
#   97,
#   106,
#   99,
#   107,
#   93,
#   89,
#   105,
#   87,
#   97,
#   109,
#   109,
#   101,
#   89,
#   90,
#   90,
#   93,
#   113,
#   89,
#   102,
#   102,
#   114,
#   130,
#   90,
#   94,
#   97,
#   143,
#   91,
#   95,
#   119,
#   93,
#   101,
#   93,
#   140,
#   135,
#   82,
#   70,
#   104,
#   117,
#   92,
#   124,
#   164,
#   93,
#   91,
#   83,
#   93,
#   114,
#   116,
#   93,
#   81,
#   84,
#   105,
#   86,
#   120,
#   92,
#   96,
#   97,
#   99,
#   100,
#   126,
#   96,
#   75,
#   94,
#   129,
#   80,
#   103,
#   96,
#   77,
#   137,
#   148,
#   123,
#   121,
#   95,
#   99,
#   104,
#   122,
#   104,
#   94,
#   176,
#   107,
#   90,
#   94,
#   101,
#   92,
#   85,
#   93,
#   22,
#   95,
#   86,
#   137,
# ...

# %%
times_dic = []
for lab, row in netflix_df.iterrows():
    if row["type"] == "Movie" and (row["release_year"] < 2000 and row["release_year"] > 1899):
        #print(row["title"])
        #print(row["release_year"])
        #print(row["duration"])
        #print(row["genre"])
        if row["duration"] not in times_dic:
            times_dic.append(row["duration"])
print(times_dic)
# Out:
# [119, 93, 176, 137, 101, 82, 95, 108, 148, 154, 96, 174, 131, 109, 147, 112, 85, 172, 122, 116, 80, 75, 129, 160, 139, 49, 90, 78, 141, 166, 103, 128, 125, 121, 89, 81, 73, 106, 25, 28, 61, 56, 94, 168, 111, 177, 99, 98, 164, 113, 87, 146, 127, 91, 117, 104, 62, 136, 165, 134, 200, 105, 170, 69, 151, 143, 163, 88, 133, 124, 118, 181, 84, 161, 115, 130, 145, 110, 149, 126, 156, 142, 193, 162, 97, 102, 173, 140, 132, 120, 86, 114, 63, 185, 153, 58, 92, 79, 100, 189, 192, 155, 138, 171, 237, 31, 187, 72, 48, 152, 178, 194, 50, 71, 228, 195, 77, 158, 135, 107, 123, 83, 18, 66, 253, 157, 42, 30, 76, 191]

# %%
movies = netflix_df[netflix_df["type"] == "Movie"]
movie_90s= movies[netflix_df["release_year"] < 2000]
short_movie_90s = movie_90s[netflix_df["duration"] < 90]
action_short_movie_90s = short_movie_90s[netflix_df["genre"] == "Action"] 
movies["duration"].plot(kind='hist')
duration = 100
#netflix_df["duration"].plot(kind='hist')
#movie_90s["duration"].plot(kind='hist')
#short_movie_90s["duration"].plot(kind='hist')
#action_short_movie_90s["duration"].plot(kind='hist')

# %%
movies = netflix_df[netflix_df["type"] == "Movie"]
movie_pre2000 = movies[netflix_df["release_year"] < 2000]
movie_90s = movie_pre2000[netflix_df["release_year"] >= 1990]
short_movie_90s = movie_90s[netflix_df["duration"] < 90]
action_short_movie_90s = short_movie_90s[netflix_df["genre"] == "Action"] 

short_movie_count = 0
for lab,row in action_short_movie_90s.iterrows():
    short_movie_count += 1

print(short_movie_count)
    #print(lab)
    #print(row)
# Out:
# 7
